# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
# After seeing the head of the data on a previous notebook, I selected just 1 school to analyze the data.
df[df['School Name'] == '47 The American Sign Language and English Secondar']
# Out:
#        School DBN                                        School Name  \
# 281        02M047  47 The American Sign Language and English Seco...
# 282        02M047  47 The American Sign Language and English Seco...
# 283        02M047  47 The American Sign Language and English Seco...
# 284        02M047  47 The American Sign Language and English Seco...
# 285        02M047  47 The American Sign Language and English Seco...
# ...           ...                                                ...
# 141024     02M047  47 The American Sign Language and English Seco...
# 141025     02M047  47 The American Sign Language and English Seco...
# 141026     02M047  47 The American Sign Language and English Seco...
# 141027     02M047  47 The American Sign Language and English Seco...
# 141028     02M047  47 The American Sign Language and English Seco...
#
#        School Level                 Regents Exam  Year  Total Tested  \
# ...

# %%
# From the school selected I want to filter the data just by the year 2017 as I just want to see the results of that year.
df[(df['School Name']== '47 The American Sign Language and English Secondar') & (df['Year'] == 2017)]
# Out:
#        School DBN                                        School Name  \
# 283        02M047  47 The American Sign Language and English Seco...
# 286        02M047  47 The American Sign Language and English Seco...
# 288        02M047  47 The American Sign Language and English Seco...
# 291        02M047  47 The American Sign Language and English Seco...
# 294        02M047  47 The American Sign Language and English Seco...
# ...           ...                                                ...
# 141013     02M047  47 The American Sign Language and English Seco...
# 141014     02M047  47 The American Sign Language and English Seco...
# 141026     02M047  47 The American Sign Language and English Seco...
# 141027     02M047  47 The American Sign Language and English Seco...
# 141028     02M047  47 The American Sign Language and English Seco...
#
#        School Level                     Regents Exam  Year  Total Tested  \
# ...

# %%
#Here I was looking to see if we have data from 2010 to present, just to have an idea of how many years the results are presented.
df[(df['School Name']== '47 The American Sign Language and English Secondar') & (df['Year'] >= 2010)]
# Out:
#        School DBN                                        School Name  \
# 281        02M047  47 The American Sign Language and English Seco...
# 282        02M047  47 The American Sign Language and English Seco...
# 283        02M047  47 The American Sign Language and English Seco...
# 284        02M047  47 The American Sign Language and English Seco...
# 285        02M047  47 The American Sign Language and English Seco...
# ...           ...                                                ...
# 141024     02M047  47 The American Sign Language and English Seco...
# 141025     02M047  47 The American Sign Language and English Seco...
# 141026     02M047  47 The American Sign Language and English Seco...
# 141027     02M047  47 The American Sign Language and English Seco...
# 141028     02M047  47 The American Sign Language and English Seco...
#
#        School Level                 Regents Exam  Year  Total Tested  \
# ...

# %%
#Removing columns that I do not need for my analysis.
drop_cols = ['Mean Score', 'Number Scoring Below 65', 'Percent Scoring Below 65', 'Number Scoring 65 or Above', 'Percent Scoring 65 or Above', 'Number Scoring CR', 'Percent Scoring CR' ]
df.drop(drop_cols, inplace = True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_5834/2727274618.py in <cell line: 0>()
#       1 drop_cols = ['Mean Score', 'Number Scoring Below 65', 'Percent Scoring Below 65', 'Number Scoring 65 or Above', 'Percent Scoring 65 or Above', 'Number Scoring CR', 'Percent Scoring CR' ]
# ----> 2 df.drop(drop_cols, inplace = True, axis=1)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
# ...

# %%
#Back to see the data only from 2017.
df[(df['School Name']== '47 The American Sign Language and English Secondar') & (df['Year'] == 2017)]
# Out:
#        School DBN                                        School Name  \
# 283        02M047  47 The American Sign Language and English Seco...
# 286        02M047  47 The American Sign Language and English Seco...
# 288        02M047  47 The American Sign Language and English Seco...
# 291        02M047  47 The American Sign Language and English Seco...
# 294        02M047  47 The American Sign Language and English Seco...
# ...           ...                                                ...
# 141013     02M047  47 The American Sign Language and English Seco...
# 141014     02M047  47 The American Sign Language and English Seco...
# 141026     02M047  47 The American Sign Language and English Seco...
# 141027     02M047  47 The American Sign Language and English Seco...
# 141028     02M047  47 The American Sign Language and English Seco...
#
#        School Level                     Regents Exam  Year  Total Tested  \
# ...

# %%
#Since I noticed that my data has inconsistent information within the columns I was trying to determine what the s means.
df[(df['School Name']== '47 The American Sign Language and English Secondar') & (df['Year'] == 2017) & (df['Percent Scoring 80 or Above'] != 's')]

# %%
#Groping data by Regents Exam, year with aggregate percent scoring 80 of above as I want to focus my comparison on this last item.
df2 = df1.groupby(['School DBN','School Level','Regents Exam','Year']).agg({'Percent Scoring 80 or Above': 'sum',})
print(df2)
# Out:
#                                                                    Percent Scoring 80 or Above
# School DBN School Level Regents Exam                    Year
# 02M047     High school  Algebra2/Trigonometry           2017                                00
#                         Common Core Algebra             2017     10.912.64.212.412.26.95.114.3
#                         Common Core Algebra2            2017                                00
#                         Common Core English             2017  53.265.716.744.481.857.141.758.1
#                         Common Core Geometry            2017                         000000000
#                         Global History and Geography    2017            182502022.75.929.412.8
#                         Living Environment              2017       9.311.90013.209.87.75.912.5
#                         Physical Settings/Earth Science 2017    10.910.911.11410.612.510.512.1
# ...

# %%
#Looking for results that don’t have actual values and not s.
df[(df['School Name']== '47 The American Sign Language and English Secondar') & (df['Year'] == 2017) & (df['Percent Scoring 80 or Above'] != 's')]
# Out:
#        School DBN                                        School Name  \
# 283        02M047  47 The American Sign Language and English Seco...
# 286        02M047  47 The American Sign Language and English Seco...
# 288        02M047  47 The American Sign Language and English Seco...
# 291        02M047  47 The American Sign Language and English Seco...
# 294        02M047  47 The American Sign Language and English Seco...
# ...           ...                                                ...
# 140999     02M047  47 The American Sign Language and English Seco...
# 141000     02M047  47 The American Sign Language and English Seco...
# 141012     02M047  47 The American Sign Language and English Seco...
# 141013     02M047  47 The American Sign Language and English Seco...
# 141027     02M047  47 The American Sign Language and English Seco...
#
#        School Level                     Regents Exam  Year  Total Tested  \
# ...

# %%
#Filtering by just one topic of the Regents Exam.
df[(df['School Name']== '47 The American Sign Language and English Secondar') & (df['Year'] == 2017) & (df['Percent Scoring 80 or Above'] != 's') & (df['Regents Exam'] == 'Common Core Algebra')]
# Out:
#        School DBN                                        School Name  \
# 286        02M047  47 The American Sign Language and English Seco...
# 19972      02M047  47 The American Sign Language and English Seco...
# 19973      02M047  47 The American Sign Language and English Seco...
# 54938      02M047  47 The American Sign Language and English Seco...
# 103419     02M047  47 The American Sign Language and English Seco...
# 103420     02M047  47 The American Sign Language and English Seco...
# 140933     02M047  47 The American Sign Language and English Seco...
# 140934     02M047  47 The American Sign Language and English Seco...
#
#        School Level         Regents Exam  Year  Total Tested  \
# 286     High school  Common Core Algebra  2017           119
# 19972   High school  Common Core Algebra  2017            95
# 19973   High school  Common Core Algebra  2017            24
# 54938   High school  Common Core Algebra  2017            89
# ...

# %%
#Realized the data type under percent scoring 80 or above is in str was trying to convert it to a number.
df1['Percent Scoring 80 or Above'] = pd.to_numeric(df1['Percent Scoring 80 or Above'])
# Out:
# /tmp/ipykernel_5834/1737870358.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Percent Scoring 80 or Above'] = pd.to_numeric(df1['Percent Scoring 80 or Above'])

# %%
#My intention was to initially select a school and within that school select one or two years to compare the results above 80 percent. Then select another school to do the same comparison of results for the same years. I was unable to complete the project as I was unable to convert some of the data from str to numerical values. I was unable to figure out what I was doing wrong to move forward with the project.
