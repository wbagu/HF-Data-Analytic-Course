# %%
# !mamba install pandas numpy matplotlib seaborn scikit-learn
# Out:
# mambajs 0.19.13
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas, seaborn, scikit-learn
# Channels: emscripten-forge, conda-forge
#
# Solving environment...
# Solving took 1.4100999999999768 seconds
#   Name                          Version                       Build                         Channel
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# + brotli-python                 1.2.0                         py313h33caa6c_0               emscripten-forge
# + certifi                       2026.2.25                     pyhd8ed1ab_0                  conda-forge
# + charset-normalizer            3.4.7                         pyhd8ed1ab_0                  conda-forge
# + idna                          3.11                          pyhd8ed1ab_0                  conda-forge
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
#Determining the info that is in the data
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 212331 entries, 0 to 212330
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   School DBN                   212331 non-null  str
#  1   School Name                  212331 non-null  str
#  2   School Level                 212331 non-null  str
#  3   Regents Exam                 212321 non-null  str
#  4   Year                         212331 non-null  int64
#  5   Total Tested                 212331 non-null  int64
#  6   Mean Score                   212331 non-null  str
#  7   Number Scoring Below 65      212331 non-null  str
#  8   Percent Scoring Below 65     212331 non-null  str
#  9   Number Scoring 65 or Above   212331 non-null  str
#  10  Percent Scoring 65 or Above  212331 non-null  str
#  11  Number Scoring 80 or Above   212331 non-null  str
#  12  Percent Scoring 80 or Above  212331 non-null  str
# ...

# %%
#Looking for a glance on how the data was entered, by showing some of the rows of data
df.head(15)
# Out:
#    School DBN                     School Name School Level  \
# 0      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3      01M140          P.S. 140 Nathan Straus          K-8
# 4      01M140          P.S. 140 Nathan Straus          K-8
# 5      01M140          P.S. 140 Nathan Straus          K-8
# 6      01M140          P.S. 140 Nathan Straus          K-8
# 7      01M140          P.S. 140 Nathan Straus          K-8
# 8      01M184            P.S. 184m Shuang Wen          K-8
# 9      01M184            P.S. 184m Shuang Wen          K-8
# 10     01M184            P.S. 184m Shuang Wen          K-8
# 11     01M184            P.S. 184m Shuang Wen          K-8
# 12     01M188      P.S. 188 The Island School          K-8
# 13     01M188      P.S. 188 The Island School          K-8
# 14     01M188      P.S. 188 The Island School          K-8
#
# ...

# %%
#Breaking down the data by Borough to determine how many schools per Borough
df['School DBN']
# Out:
# 0         01M034
# 1         01M034
# 2         01M034
# 3         01M140
# 4         01M140
#            ...
# 212326    84X717
# 212327    84X717
# 212328    84X717
# 212329    84X717
# 212330    84X717
# Name: School DBN, Length: 212331, dtype: str

# %%
#Trying to see if by school name will have a different visualization

# %%
df['School Name']
# Out:
# 0         P.S. 034 Franklin D. Roosevelt
# 1         P.S. 034 Franklin D. Roosevelt
# 2         P.S. 034 Franklin D. Roosevelt
# 3                 P.S. 140 Nathan Straus
# 4                 P.S. 140 Nathan Straus
#                        ...
# 212326              Icahn Charter School
# 212327              Icahn Charter School
# 212328              Icahn Charter School
# 212329              Icahn Charter School
# 212330              Icahn Charter School
# Name: School Name, Length: 212331, dtype: str

# %%
# !mamba install pandas numpy matplotlib seaborn scikit-learn
# Out:
# mambajs 0.19.13
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas, seaborn, scikit-learn
# Channels: emscripten-forge, conda-forge
#
# Solving environment...
# Solving took 2.005 seconds
#   Name                          Version                       Build                         Channel
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# + brotli-python                 1.2.0                         py313h33caa6c_0               emscripten-forge
# + certifi                       2026.2.25                     pyhd8ed1ab_0                  conda-forge
# + charset-normalizer            3.4.7                         pyhd8ed1ab_0                  conda-forge
# + idna                          3.11                          pyhd8ed1ab_0                  conda-forge
# + joblib                        1.5.3                         py313h1804a44_1               emscripten-forge
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
#Looking just at the school names
print(df["School Name"].unique())
# Out:
# <StringArray>
# [                    'P.S. 034 Franklin D. Roosevelt',
#                              'P.S. 140 Nathan Straus',
#                                'P.S. 184m Shuang Wen',
#                          'P.S. 188 The Island School',
#                          'Orchard Collegiate Academy',
#               'Technology, Arts, and Sciences Studio',
#               'University Neighborhood Middle School',
#  'Collaborative Academy of Science, Technology, & La',
#                           'School for Global Leaders',
#                 'University Neighborhood High School',
#  ...
#                       'American Dream Charter School',
#  'Dr. Richard Izquierdo Health and Science Charter S',
#       'Girls Preparatory Charter School of the Bronx',
#                         'The Equality Charter School',
#                              'Icahn Charter School 4',
#                'South Bronx Community Charter School',
#                         'KIPP Academy Charter School',
# ...

# %%
for school in df["School Name"].unique():
    print(school)
# Out:
# P.S. 034 Franklin D. Roosevelt
# P.S. 140 Nathan Straus
# P.S. 184m Shuang Wen
# P.S. 188 The Island School
# Orchard Collegiate Academy
# Technology, Arts, and Sciences Studio
# University Neighborhood Middle School
# Collaborative Academy of Science, Technology, & La
# School for Global Leaders
# University Neighborhood High School
# East Side Community School
# Forsyth Satellite Academy
# Marta Valle High School
# Lower East Side Preparatory High School
# New Explorations into Science, Technology and Math
# Cascades High School
# Bard High School Early College
# Tompkins Square Middle School
# 47 The American Sign Language and English Secondar
# J.H.S. 104 Simon Baruch
# P.S. 111 Adolph S. Ochs
# East Side Middle School
# P.S. 126 Jacob August Riis
# M.S. 131
# The Urban Assembly School for Emergency Management
# Stephen T. Mather Building Arts & Craftsmanship Hi
# J.H.S. 167 Robert F. Wagner
# Yorkville East Middle School
# P.S./I.S. 217 Roosevelt Island
# ...

# %%
#Trying to determine how many districs are in the data
print(df["School DBN"].unique())
# Out:
# <StringArray>
# ['01M034', '01M140', '01M184', '01M188', '01M292', '01M301', '01M332',
#  '01M345', '01M378', '01M448',
#  ...
#  '84X487', '84X488', '84X496', '84X539', '84X553', '84X581', '84X704',
#  '84X705', '84X706', '84X717']
# Length: 1018, dtype: str

# %%
df["District"] = df["School DBN"].str[:2]

# %%
district_schools = df.groupby("District")["School Name"].unique()

for district, schools in district_schools.items():
    print(f"\nDistrict {district}:")
    for school in schools:
        print(school)
# Out:
# District 01:
# P.S. 034 Franklin D. Roosevelt
# P.S. 140 Nathan Straus
# P.S. 184m Shuang Wen
# P.S. 188 The Island School
# Orchard Collegiate Academy
# Technology, Arts, and Sciences Studio
# University Neighborhood Middle School
# Collaborative Academy of Science, Technology, & La
# School for Global Leaders
# University Neighborhood High School
# East Side Community School
# Forsyth Satellite Academy
# Marta Valle High School
# Lower East Side Preparatory High School
# New Explorations into Science, Technology and Math
# Cascades High School
# Bard High School Early College
# Tompkins Square Middle School
#
# District 02:
# 47 The American Sign Language and English Secondar
# J.H.S. 104 Simon Baruch
# P.S. 111 Adolph S. Ochs
# East Side Middle School
# P.S. 126 Jacob August Riis
# M.S. 131
# The Urban Assembly School for Emergency Management
# Stephen T. Mather Building Arts & Craftsmanship Hi
# J.H.S. 167 Robert F. Wagner
# Yorkville East Middle School
# ...

# %%
print(df["School Name"].count())
# Out:
# 212331

# %%
district_schools = df.groupby("District")["School DBN"].unique()

for district, schools in district_schools.items():
    print(f"\nDistrict {district} (Total Schools: {len(schools)}):")

for school in schools:
    print(school)
# Out:
# District 01 (Total Schools: 18):
#
# District 02 (Total Schools: 90):
#
# District 03 (Total Schools: 30):
#
# District 04 (Total Schools: 21):
#
# District 05 (Total Schools: 14):
#
# District 06 (Total Schools: 26):
#
# District 07 (Total Schools: 31):
#
# District 08 (Total Schools: 38):
#
# District 09 (Total Schools: 38):
#
# District 10 (Total Schools: 54):
#
# District 11 (Total Schools: 35):
#
# District 12 (Total Schools: 29):
#
# District 13 (Total Schools: 27):
#
# District 14 (Total Schools: 23):
#
# District 15 (Total Schools: 21):
#
# District 16 (Total Schools: 16):
#
# District 17 (Total Schools: 35):
#
# District 18 (Total Schools: 25):
#
# District 19 (Total Schools: 34):
#
# District 20 (Total Schools: 20):
#
# District 21 (Total Schools: 26):
#
# District 22 (Total Schools: 16):
#
# District 23 (Total Schools: 21):
#
# District 24 (Total Schools: 30):
#
# District 25 (Total Schools: 24):
#
# District 26 (Total Schools: 13):
#
# District 27 (Total Schools: 34):
#
# ...

# %%
#Trying to get a visualization of the schools, but is too much data
df['School DBN'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='School DBN'>

# %%
# !mamba install pandas numpy matplotlib seaborn scikit-learn
# Out:
# mambajs 0.19.13
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas, seaborn, scikit-learn
# Channels: emscripten-forge, conda-forge
#
# Solving environment...
# Solving took 1.39 seconds
#   Name                          Version                       Build                         Channel
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# + brotli-python                 1.2.0                         py313h33caa6c_0               emscripten-forge
# + certifi                       2026.2.25                     pyhd8ed1ab_0                  conda-forge
# + charset-normalizer            3.4.7                         pyhd8ed1ab_0                  conda-forge
# + idna                          3.11                          pyhd8ed1ab_0                  conda-forge
# + joblib                        1.5.3                         py313h1804a44_1               emscripten-forge
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
#Starting again, looking for the details of the data

df.describe()
# Out:
#                 Year   Total Tested
# count  212331.000000  212331.000000
# mean     2015.956069      49.364200
# std         0.799726      93.023576
# min      2015.000000       1.000000
# 25%      2015.000000       5.000000
# 50%      2016.000000      20.000000
# 75%      2017.000000      57.000000
# max      2017.000000    1729.000000

# %%
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# ...

# %%
df.groupby(['School DBN'])['School Name'].count()
# Out:
# School DBN
# 01M034     29
# 01M140     41
# 01M184     49
# 01M188     57
# 01M292    354
#          ...
# 84X703    383
# 84X704    351
# 84X705     26
# 84X706     43
# 84X717     50
# Name: School Name, Length: 1018, dtype: int64

# %%
df['School DBN'].count()
# Out:
# np.int64(212331)

# %%
df['School DBN'].unique()
# Out:
# <StringArray>
# ['01M034', '01M140', '01M184', '01M188', '01M292', '01M301', '01M332',
#  '01M345', '01M378', '01M448',
#  ...
#  '84X487', '84X488', '84X496', '84X539', '84X553', '84X581', '84X704',
#  '84X705', '84X706', '84X717']
# Length: 1018, dtype: str

# %%
df['School Name'].unique()
# Out:
# <StringArray>
# [                    'P.S. 034 Franklin D. Roosevelt',
#                              'P.S. 140 Nathan Straus',
#                                'P.S. 184m Shuang Wen',
#                          'P.S. 188 The Island School',
#                          'Orchard Collegiate Academy',
#               'Technology, Arts, and Sciences Studio',
#               'University Neighborhood Middle School',
#  'Collaborative Academy of Science, Technology, & La',
#                           'School for Global Leaders',
#                 'University Neighborhood High School',
#  ...
#                       'American Dream Charter School',
#  'Dr. Richard Izquierdo Health and Science Charter S',
#       'Girls Preparatory Charter School of the Bronx',
#                         'The Equality Charter School',
#                              'Icahn Charter School 4',
#                'South Bronx Community Charter School',
#                         'KIPP Academy Charter School',
# ...

# %%
df.groupby(['School Name']).count().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df.groupby(['School Name']).count().sort_values(ascending=False)
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
df2=df[['School Name','School DBN']]

# %%
df2
# Out:
#                            School Name School DBN
# 0       P.S. 034 Franklin D. Roosevelt     01M034
# 1       P.S. 034 Franklin D. Roosevelt     01M034
# 2       P.S. 034 Franklin D. Roosevelt     01M034
# 3               P.S. 140 Nathan Straus     01M140
# 4               P.S. 140 Nathan Straus     01M140
# ...                                ...        ...
# 212326            Icahn Charter School     84X717
# 212327            Icahn Charter School     84X717
# 212328            Icahn Charter School     84X717
# 212329            Icahn Charter School     84X717
# 212330            Icahn Charter School     84X717
#
# [212331 rows x 2 columns]

# %%
df['Regents Exam'].unique()
# Out:
# <StringArray>
# [            'Common Core Algebra',              'Living Environment',
#              'Common Core English',           'Algebra2/Trigonometry',
#             'Common Core Algebra2',            'Common Core Geometry',
#                          'English',                        'Geometry',
#     'Global History and Geography',              'Integrated Algebra',
#      'Physical Settings/Chemistry', 'Physical Settings/Earth Science',
#      'U.S. History and Government',       'Physical Settings/Physics',
#                                nan]
# Length: 15, dtype: str

# %%
df.groupby(['School Name'])['Regents Exam'].count()
# Out:
# School Name
# 47 The American Sign Language and English Secondar    356
# A. Philip Randolph Campus High School                 459
# ACORN Community High School                           364
# Abraham Lincoln High School                           480
# Abraham Lincoln Yabc                                  248
#                                                      ...
# Young Women's Leadership School                       378
# Young Women's Leadership School of Brooklyn           337
# Young Women's Leadership School of the Bronx          142
# Young Women's Leadership School, Astoria              338
# Young Women's Leadership School, Queens               391
# Name: Regents Exam, Length: 1012, dtype: int64

# %%
df.groupby(['School Name'])

# %%
#Getting specific by one type of Regents Exam

df[df['Regents Exam'] == 'English']
# Out:
#        School DBN                          School Name      School Level  \
# 31         01M292           Orchard Collegiate Academy       High school
# 32         01M292           Orchard Collegiate Academy       High school
# 73         01M448  University Neighborhood High School       High school
# 74         01M448  University Neighborhood High School       High school
# 101        01M450           East Side Community School  Secondary School
# ...           ...                                  ...               ...
# 212152     84X703     Bronx Preparatory Charter School  Secondary School
# 212251     84X704          KIPP Academy Charter School   K-12 all grades
# 212252     84X704          KIPP Academy Charter School   K-12 all grades
# 212253     84X704          KIPP Academy Charter School   K-12 all grades
# 212254     84X704          KIPP Academy Charter School   K-12 all grades
#
#        Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# ...

# %%
#Getting data from one school I'll focus my first comparison just by this school.

df[df['School Name'] == '47 The American Sign Language and English Secondar']
# Out:
#        School DBN                                        School Name  \
# 281        02M047  47 The American Sign Language and English Seco...
# 282        02M047  47 The American Sign Language and English Seco...
# 283        02M047  47 The American Sign Language and English Seco...
# 284        02M047  47 The American Sign Language and English Seco...
# 285        02M047  47 The American Sign Language and English Seco...
# ...           ...                                                ...
# 141024     02M047  47 The American Sign Language and English Seco...
# 141025     02M047  47 The American Sign Language and English Seco...
# 141026     02M047  47 The American Sign Language and English Seco...
# 141027     02M047  47 The American Sign Language and English Seco...
# 141028     02M047  47 The American Sign Language and English Seco...
#
#        School Level                 Regents Exam  Year  Total Tested  \
# ...

# %%
#Trying anotehr visualization 

df[df['School Name'] == '47 The American Sign Language and English Secondar'].hist()
# Out:
# array([[<Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Total Tested'}>]], dtype=object)

# %%
df.groupby(['School DBN'])['School Name'].count()
# Out:
# School DBN
# 01M034     29
# 01M140     41
# 01M184     49
# 01M188     57
# 01M292    354
#          ...
# 84X703    383
# 84X704    351
# 84X705     26
# 84X706     43
# 84X717     50
# Name: School Name, Length: 1018, dtype: int64

# %%
df1=df[(df['School Name'] == '47 The American Sign Language and English Secondar') & (df['Regents Exam'] == 'English')]

# %%
print(df1)
# Out:
#        School DBN                                        School Name  \
# 295        02M047  47 The American Sign Language and English Seco...
# 296        02M047  47 The American Sign Language and English Seco...
# 19988      02M047  47 The American Sign Language and English Seco...
# 19989      02M047  47 The American Sign Language and English Seco...
# 19990      02M047  47 The American Sign Language and English Seco...
# 19991      02M047  47 The American Sign Language and English Seco...
# 54959      02M047  47 The American Sign Language and English Seco...
# 54960      02M047  47 The American Sign Language and English Seco...
# 54961      02M047  47 The American Sign Language and English Seco...
# 54962      02M047  47 The American Sign Language and English Seco...
# 54963      02M047  47 The American Sign Language and English Seco...
# 54964      02M047  47 The American Sign Language and English Seco...
# 103437     02M047  47 The American Sign Language and English Seco...
# ...

# %%
df[df['School Name'] == '47 The American Sign Language and English Secondar'].count()
# Out:
# School DBN                     356
# School Name                    356
# School Level                   356
# Regents Exam                   356
# Year                           356
# Total Tested                   356
# Mean Score                     356
# Number Scoring Below 65        356
# Percent Scoring Below 65       356
# Number Scoring 65 or Above     356
# Percent Scoring 65 or Above    356
# Number Scoring 80 or Above     356
# Percent Scoring 80 or Above    356
# Number Scoring CR              356
# Percent Scoring CR             356
# dtype: int64

# %%
df.count()
# Out:
# School DBN                     212331
# School Name                    212331
# School Level                   212331
# Regents Exam                   212321
# Year                           212331
# Total Tested                   212331
# Mean Score                     212331
# Number Scoring Below 65        212331
# Percent Scoring Below 65       212331
# Number Scoring 65 or Above     212331
# Percent Scoring 65 or Above    212331
# Number Scoring 80 or Above     212331
# Percent Scoring 80 or Above    212331
# Number Scoring CR              212331
# Percent Scoring CR             212331
# dtype: int64
